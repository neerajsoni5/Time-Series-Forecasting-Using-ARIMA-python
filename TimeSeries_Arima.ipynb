# %%
#If you use only the previous values of the time series to predict its future values, it is called Univariate Time Series Forecasting.
#if you use predictors other than the series (a.k.a exogenous variables) to forecast it is called Multi Variate Time Series Forecasting.

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# %%
# Import data
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/wwwusage.csv', names=['value'], header=0)

# %%
df.head()
# Out:
#    value
# 0     88
# 1     84
# 2     85
# 3     85
# 4     84

# %%
# plot Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df.value); axes[0, 0].set_title('Original Series')
plot_acf(df.value, ax=axes[0, 1])


# 1st Differencing
axes[1, 0].plot(df.value.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.value.diff().dropna(), ax=axes[1, 1])


# 2nd Differencing
axes[2, 0].plot(df.value.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.value.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
#With lag 2 differencing sereis seems more stable, but at the ame time ACF Plots shows that 
#it might be overdifferenced as most of the values are in negatives
#So go with Order 1

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\n.kumar.soni\appdata\roaming\python\python37\site-packages (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: Cython<0.29.18,>=0.29 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pmdarima) (0.29.13)
# Requirement already satisfied: pandas>=0.19 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pmdarima) (0.25.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\n.kumar.soni\appdata\roaming\python\python37\site-packages (from pmdarima) (0.23.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pmdarima) (1.19.0)
# Requirement already satisfied: statsmodels>=0.11 in c:\users\n.kumar.soni\appdata\roaming\python\python37\site-packages (from pmdarima) (0.11.1)
# Requirement already satisfied: urllib3 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pmdarima) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2019.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from statsmodels>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\n.kumar.soni\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.12.0)

# %%
import pmdarima as pmd
from pmdarima.arima import auto_arima
#from pmdarima.arima.utils import ndiffs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-0488d7525d60> in <module>
# ----> 1 import pmdarima as pmd
#       2 from pmdarima.arima import auto_arima
#       3 #from pmdarima.arima.utils import ndiffs
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
from pyramid.arima import auto_arima
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-4e35d3e40b01> in <module>
# ----> 1 from pyramid.arima import auto_arima
#
# ModuleNotFoundError: No module named 'pyramid'

# %%
# !pip install pyramid-arima
